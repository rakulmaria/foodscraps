# %% [markdown]
# # Model Comparison
#
# Comparison was done using the following tools:
#
# - [OpenCode - Compare AI Models](https://opencode.ai/data/compare/openai/gpt-5-5/openai/gpt-5-6-terra)
# - [AI Models Directory](https://llmgateway.io/models?view=table&filters=1&webSearch=true&vision=true&sortField=provider&sortDir=asc&category=reasoning)
#
# ## Anthropic / Claude
#
# | Model           | Input $/M   | Output $/M  | Cache R $/M |
# | --------------- | ----------- | ----------- | ----------- |
# | `opus-4.8` + `5`| $5          | $25         | $0.5        |
# | `sonnet-5`      | $2          | $10         | $0.2        |
#
# **Conclusion:** `claude-sonnet-5`
#
# ## OpenaAI / GPT
#
# | Model           | Input $/M   | Output $/M  | Cache R $/M |
# | --------------- | ----------- | ----------- | ----------- |
# | `gpt-5.5`       | $5          | $30         | $0.5        |
# | `gpt-5.6-terra` | $2          | $12         | $0.2        |
# | `gpt-5.6-luna`  | $0.2        | $1.2        | $0.02       |
#
# However, luna actually performed best in the mini test. So maybe go with luna ?
#
# **Conclusion:** `gpt-5.6-terra`
#
# ## Google AI Studio
#
# | Model           | Input $/M   | Output $/M  | Cache R $/M |
# | --------------- | ----------- | ----------- | ----------- |
# | `gemini-3.5`    | $1.5        | $9.0        | $0.15       |
# | `gemini-3.8`    | $0.75       | $3.75       | $0.07       |
#
# **Conclusion:** `gemini-3.8-flash`
