# %%
from googleapi import *

# %%
place = find_aggregated_places()
# Out:
# ! ERROR: 429

# %%
print(place['error']['message'])
# Out:
# The response exceeded the maximum number of allowed places. Only 100 places can be returned in a single response. The request produced 2648 places and therefore no places were returned.

# %% [markdown]
# > The response exceeded the maximum number of allowed places. Only 100 places can be returned in a single response. The request produced **2648** places and therefore no places were returned.
